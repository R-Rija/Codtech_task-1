# %% [markdown]
# ## imports and reading

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
pd.set.option('max_column',200)

# %%
df=pd.read_csn("D:\data analysts projects\EDA project\coaster_db.csv")

# %% [markdown]
# ## Data Understanding

# %%
df.shape

# %%
df.head()

# %%
df.columns

# %%
df.dtypes
